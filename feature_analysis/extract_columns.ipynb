# %%
import pandas as pd

# %%
df = pd.read_csv('../source_data/extracted/articles.A-B.xml.tar.gz.csv')
df2 = pd.read_csv('../source_data/extracted/articles.C-H.xml.tar.gz.csv')
df3 = pd.read_csv('../source_data/extracted/articles.I-N.xml.tar.gz.csv')
df4 = pd.read_csv('../source_data/extracted/articles.O-Z.xml.tar.gz.csv')

# %%
df['ack_absent'] = df.Acknowledgment_Tag.isna()

print(df)
# Out:
#                                     filename  \
# 0         20_Century_Br_Hist/PMC4804230.nxml
# 1         20_Century_Br_Hist/PMC5905639.nxml
# 2               3D_Print_Med/PMC5954787.nxml
# 3               3D_Print_Med/PMC5954788.nxml
# 4               3D_Print_Med/PMC5954789.nxml
# 5               3D_Print_Med/PMC5954790.nxml
# 6               3D_Print_Med/PMC5954791.nxml
# 7               3D_Print_Med/PMC5954792.nxml
# 8               3D_Print_Med/PMC5954793.nxml
# 9               3D_Print_Med/PMC5954794.nxml
# 10              3D_Print_Med/PMC5954795.nxml
# 11              3D_Print_Med/PMC5954796.nxml
# 12              3D_Print_Med/PMC5954797.nxml
# 13              3D_Print_Med/PMC5954798.nxml
# 14              3D_Print_Med/PMC5954799.nxml
# 15              3D_Print_Med/PMC5970151.nxml
# 16              3D_Print_Med/PMC6027614.nxml
# 17              3D_Print_Med/PMC6036609.nxml
# 18              3D_Print_Med/PMC6036611.nxml
# 19              3D_Print_Med/PMC6036663.nxml
# ...

# %%
#Reduce the file complexity by dropping the Acknowledgment_Tag
df = df.drop(labels={'Acknowledgment_Tag'}, axis=1)

print(df)
# Out:
#                                     filename  ack_absent
# 0         20_Century_Br_Hist/PMC4804230.nxml       False
# 1         20_Century_Br_Hist/PMC5905639.nxml       False
# 2               3D_Print_Med/PMC5954787.nxml       False
# 3               3D_Print_Med/PMC5954788.nxml       False
# 4               3D_Print_Med/PMC5954789.nxml       False
# 5               3D_Print_Med/PMC5954790.nxml       False
# 6               3D_Print_Med/PMC5954791.nxml       False
# 7               3D_Print_Med/PMC5954792.nxml       False
# 8               3D_Print_Med/PMC5954793.nxml       False
# 9               3D_Print_Med/PMC5954794.nxml       False
# 10              3D_Print_Med/PMC5954795.nxml       False
# 11              3D_Print_Med/PMC5954796.nxml       False
# 12              3D_Print_Med/PMC5954797.nxml       False
# 13              3D_Print_Med/PMC5954798.nxml       False
# 14              3D_Print_Med/PMC5954799.nxml       False
# ...

# %%
df.to_csv('../parsed_data/cleaned_data/articles.A-B.xml.tar.gz_reduced.csv')

# %%
df2['ack_absent'] = df2.Acknowledgment_Tag.isna()
df2 = df2.drop(labels={'Acknowledgment_Tag'}, axis=1)
df2.to_csv('../parsed_data/cleaned_data/articles.C-H.xml.tar.gz_reduced.csv')

df3['ack_absent'] = df3.Acknowledgment_Tag.isna()
df3 = df3.drop(labels={'Acknowledgment_Tag'}, axis=1)
df3.to_csv('../parsed_data/cleaned_data/articles.I-N.xml.tar.gz_reduced.csv')

df4['ack_absent'] = df4.Acknowledgment_Tag.isna()
df4 = df4.drop(labels={'Acknowledgment_Tag'}, axis=1)
df4.to_csv('../parsed_data/cleaned_data/articles.O-Z.xml.tar.gz_reduced.csv')

# %%
print(df.ack_absent.value_counts())

print(df2.ack_absent.value_counts())

print(df3.ack_absent.value_counts())

print(df4.ack_absent.value_counts())
# Out:
# False    209856
# True     168989
# Name: ack_absent, dtype: int64
# False    235079
# True     229088
# Name: ack_absent, dtype: int64
# True     327600
# False    325844
# Name: ack_absent, dtype: int64
# False    402376
# True     207704
# Name: ack_absent, dtype: int64

# %%
print(list(df))

print(list(df2))

print(list(df3))

print(list(df4))
# Out:
# ['filename', 'ack_absent']
# ['filename', 'ack_absent']
# ['filename', 'ack_absent']
# ['filename', 'ack_absent']
